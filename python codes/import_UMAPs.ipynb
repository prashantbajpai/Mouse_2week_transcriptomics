# %%
import scanpy as sc
import numpy as np
import pandas as pd

# %%
adata = sc.read_h5ad('/Users/pbajpai/Library/CloudStorage/OneDrive-EmoryUniversity/pbajpai/KIT/Kit_10x/rds_obs/macro_Aug122024.h5ad')
# Out:
# /Users/pbajpai/miniconda3/lib/python3.10/site-packages/anndata/compat/__init__.py:311: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
adata.obs.columns = adata.obs.columns.str.replace(".","_", regex=False)
adata.obs.columns
# Out:
# Index(['orig_ident', 'nCount_RNA', 'nFeature_RNA', 'percent_mt', 'percent_hb',
#        'percent_rb', 'SampleID', 'Group', 'RNA_snn_res_0_5', 'seurat_clusters',
#        'doublet_classification_low_confidence',
#        'doublet_classification_high_confidence',
#        'doubletFinder_classification', 'label_main', 'label_fine',
#        'RNA_snn_res_0_16', 'RNA_snn_res_0_12', 'RNA_snn_res_0_2',
#        'label_main_new', 'RNA_snn_res_0_05', 'RNA_snn_res_0_03',
#        'RNA_snn_res_0_02', 'RNA_snn_res_0_025', 'RNA_snn_res_0_04',
#        'RNA_snn_res_0_1', 'label_manual', 'label_main_new2', 'label_subset'],
#       dtype='object')

# %%
adata.obs
# Out:
#                    orig_ident  nCount_RNA  nFeature_RNA  percent_mt  \
# AAAGATGGTGGGTCAA-1    lung10x      5030.0          2054    4.592445
# AAAGTAGCAGTCAGCC-1    lung10x      4462.0          1687    4.370238
# AAAGTAGCATACTCTT-1    lung10x      3558.0          1572    5.593030
# AACACGTTCACAAACC-1    lung10x      7174.0          2253    2.286033
# AACCGCGCAAGAGGCT-1    lung10x      9852.0          3116    4.841657
# ...                       ...         ...           ...         ...
# TTGGCAAAGGTGATAT-9    lung10x      3873.0          1574    6.145107
# TTGGCAACATACAGCT-9    lung10x      2361.0          1275    5.717916
# TTTACTGTCGCCCTTA-9    lung10x      3976.0          1671    2.892354
# TTTATGCGTGTGGTTT-9    lung10x      3734.0          1582    4.793787
# TTTCCTCAGACCACGA-9    lung10x      3313.0          1522    5.976456
#
#                     percent_hb  percent_rb SampleID       Group  \
# AAAGATGGTGGGTCAA-1    0.974155   16.461233        1  Uninfected
# ...

# %%
adata.obs['barcode_orig'] = adata.obs.index

# %%
adata.obs
# Out:
#                    orig_ident  nCount_RNA  nFeature_RNA  percent_mt  \
# AAAGATGGTGGGTCAA-1    lung10x      5030.0          2054    4.592445
# AAAGTAGCAGTCAGCC-1    lung10x      4462.0          1687    4.370238
# AAAGTAGCATACTCTT-1    lung10x      3558.0          1572    5.593030
# AACACGTTCACAAACC-1    lung10x      7174.0          2253    2.286033
# AACCGCGCAAGAGGCT-1    lung10x      9852.0          3116    4.841657
# ...                       ...         ...           ...         ...
# TTGGCAAAGGTGATAT-9    lung10x      3873.0          1574    6.145107
# TTGGCAACATACAGCT-9    lung10x      2361.0          1275    5.717916
# TTTACTGTCGCCCTTA-9    lung10x      3976.0          1671    2.892354
# TTTATGCGTGTGGTTT-9    lung10x      3734.0          1582    4.793787
# TTTCCTCAGACCACGA-9    lung10x      3313.0          1522    5.976456
#
#                     percent_hb  percent_rb SampleID       Group  \
# AAAGATGGTGGGTCAA-1    0.974155   16.461233        1  Uninfected
# ...
